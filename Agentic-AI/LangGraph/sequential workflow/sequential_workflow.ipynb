# %% [markdown]
# ### Workflows
# ![image.png](attachment:image.png)
#
# - LLM workfows are step-by-step process using which we can build complex LLM application
# - Each workflow can preform complex task such as prompting, reasoning, tool calling, memory access
# - workflows can be parallel, linear, branched, looped

# %%
from langgraph.graph import StateGraph
# Out:
# Running cells with 'agentic_venv (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Codebase/Agentic-AI/agentic_venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
