# %%
from langgraph.graph  import StateGraph, START , END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
import os
from dotenv import load_dotenv

# Load the .env file explicitly
load_dotenv(dotenv_path='D:/Codebase/Agentic-AI/.env')

# Now access the variable
api_key = os.getenv("OPENAI_API_KEY")
print("API Key:", api_key)
# Out:
# API Key: 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

# %%
model=ChatOpenAI()

# %%
#create a state

class LLMState(TypedDict):
    
    question : str
    answer : str

# %%
def llm_qa(state : LLMState) -> LLMState :

    #extract the question from the state
    question=state['question']

    #create a prompt
    prompt=f'Answer the following question {question}'

    #ask question to the llm
    answer=model.invoke(prompt).content

    #update the answer to the state
    state['answer']=answer

    return state

# %%
#create your graph
graph=StateGraph(LLMState)

graph.add_node('llm_qa',llm_qa)

graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

#compile the graph
workflow=graph.compile()

# %%
#execute
initial_state={'question': 'nature and ecosystem'}
final_state=workflow.invoke(initial_state)
print(final_state)
# Out:
# {'question': 'nature and ecosystem', 'answer': 'Nature is the natural world around us, including plants, animals, landscapes, and natural phenomena. Ecosystems are the complex interactions of living organisms and their environment, including both biotic (living) and abiotic (non-living) components. Ecosystems are crucial for sustaining life on Earth as they provide essential services like clean water, air, and food, as well as regulating climate and supporting biodiversity. Additionally, ecosystems are interconnected and rely on the balance and interactions between different species to thrive.'}
